# %%
import mysql.connector
import pandas as pd

# %%
database = mysql.connector.connect(host="localhost",user="root",passwd= "Rakhi@97",database="Hospital")
cursor = database.cursor()

# %%
df = pd.read_sql('SELECT * FROM customer', con=database)

# %%
df
# Out:
#     Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0           124         Rakhi  2021-10-03          2022-10-04            COV
# 1           956       Kriston  2021-09-07          2022-09-04            MVD
# 2           957         Perry  2021-09-08          2022-09-04            MVD
# 3           959           Joe  2021-09-09          2022-09-04            MVD
# 4           960        Volter  2021-09-10          2022-09-04            MVD
# 5           961         Javed  2021-09-08          2022-09-04            MVD
# 6           962         Rajan  2021-09-10          2022-09-04            MVD
# 7           963         Jully  2021-09-05          2022-09-04            MVD
# 8           964         Bella  2021-09-11          2022-09-04            COV
# 9           966        Cherry  2021-09-05          2022-09-06            MVD
# 10          967         Suzan  2021-09-05          2022-09-04            MVD
# ...

# %%
Ind_df= pd.read_sql("SELECT * FROM customer where Country='IND'", con=database)

# %%
Ind_df
# Out:
#    Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0          124         Rakhi  2021-10-03          2022-10-04            COV
# 1          962         Rajan  2021-09-10          2022-09-04            MVD
# 2          970     Rushikesh  2021-09-10          2022-09-04            MVD
#
#    Dr_Name State Country         DOB Is_Active
# 0  Gaikwad    MH     IND  1997-08-18         A
# 1       CV    PB     IND  1992-11-18         A
# 2      COV    KL     IND  1998-11-18         A

# %%
Ind_df= pd.read_sql("SELECT * FROM customer where Country='IND'", con=database).to_csv('D:/incubyteassement/India_data.csv')

# %%
UAE_df= pd.read_sql("SELECT * FROM customer where Country='UAE'", con=database)

# %%
UAE_df
# Out:
#    Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0          960        Volter  2021-09-10          2022-09-04            MVD
# 1          961         Javed  2021-09-08          2022-09-04            MVD
#
#   Dr_Name State Country         DOB Is_Active
# 0    Zoya    DB     UAE  1990-11-12         A
# 1   Nihad    DB     UAE  1993-08-12         A

# %%
UAE_df= pd.read_sql("SELECT * FROM customer where Country='UAE'", con=database).to_csv('D:/incubyteassement/UAE_data.csv')

# %%
AU_df= pd.read_sql("SELECT * FROM customer where Country='AU'", con=database)

# %%
AU_df
# Out:
#    Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0          956       Kriston  2021-09-07          2022-09-04            MVD
# 1          959           Joe  2021-09-09          2022-09-04            MVD
# 2          966        Cherry  2021-09-05          2022-09-06            MVD
#
#   Dr_Name State Country         DOB Is_Active
# 0     Bob   VIC      AU  1990-08-13         A
# 1     Rob   VIC      AU  1989-12-08         A
# 2    John   VIC      AU  1990-11-12         A

# %%
AU_df= pd.read_sql("SELECT * FROM customer where Country='AU'", con=database).to_csv('D:/incubyteassement/Aus_data.csv')

# %%
NYC_df= pd.read_sql("SELECT * FROM customer where Country='NYC'", con=database)

# %%
NYC_df
# Out:
#    Customer_Id Customer_Name   Open_date Last_Consulted_Date Vaccination_Id  \
# 0          968         Jacob  2021-09-05          2022-09-04            MVD
#
#   Dr_Name State Country         DOB Is_Active
# 0   Jerry    NM     NYC  1991-06-06         A

# %%
NYC_df= pd.read_sql("SELECT * FROM customer where Country='NYC'", con=database).to_csv('D:/incubyteassement/NYC_data.csv')

# %%
USA_df= pd.read_sql("SELECT * FROM customer where Country='USA'", con=database).to_csv('D:/incubyteassement/USA_data.csv')

# %%
USA_df

# %%
JPN_df= pd.read_sql("SELECT * FROM customer where Country='JPN'", con=database).to_csv('D:/incubyteassement/JPN_data.csv')

# %%
JPN_df
